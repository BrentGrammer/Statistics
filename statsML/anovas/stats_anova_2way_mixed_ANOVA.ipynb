# %% [markdown]
# # COURSE: Master statistics and machine learning: Intuition, Math, code
# ##### COURSE URL: udemy.com/course/statsml_x/?couponCode=202304
# ## SECTION: ANOVA
# ### VIDEO: Two-way mixed-effects ANOVA
# #### TEACHER: Mike X Cohen, sincxpress.com

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import pingouin as pg
import pandas as pd
import seaborn as sns
# Out:
# c:\anaconda\envs\pytorch2023\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.3, the latest is 0.5.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
## the data and group labels

# using numpy to import data from a csv file
data = np.loadtxt(open("TwoWayMixedANOVA_data.csv"),delimiter=",")

timepoint = ['1']*45 + ['2']*45 + ['3']*45
groups    = ['1']*15 + ['2']*15 + ['3']*15
s = []
for i in range(45):
    s += [str(i)]

# # convert to pandas
df = pd.DataFrame(data=np.matrix.flatten(data,'F'),columns=['TheData'])
df['Group'] = np.tile(groups,3)
df['TimePoint'] = timepoint
df['Subject'] = np.tile(s,3)

pd.set_option("display.max_rows", None, "display.max_columns", None)
df

# 1 row per data point
# column indicates between subjects factor (which group of coffee drinkers)
# Timepoint col represents whether the score is from before, during or after drinking coffee
# Subject col is the subject id for the participant within each of the three groups
# Out:
#      TheData Group TimePoint Subject
# 0       13.0     1         1       0
# 1       15.0     1         1       1
# 2       13.0     1         1       2
# 3       16.0     1         1       3
# 4       17.0     1         1       4
# 5       18.0     1         1       5
# 6       16.0     1         1       6
# 7       16.0     1         1       7
# 8       18.0     1         1       8
# 9       17.0     1         1       9
# 10      17.0     1         1      10
# 11      19.0     1         1      11
# 12      18.0     1         1      12
# 13      19.0     1         1      13
# 14      22.0     1         1      14
# 15      14.0     2         1      15
# 16      16.0     2         1      16
# 17      15.0     2         1      17
# 18      16.0     2         1      18
# 19      16.0     2         1      19
# 20      16.0     2         1      20
# 21      16.0     2         1      21
# 22      17.0     2         1      22
# 23      17.0     2         1      23
# ...

# %%
# use the function from pengouin package for mixed anovas:
pg.mixed_anova(data=df,dv='TheData',between='Group',within='TimePoint',subject='Subject')
# the within factor is the repeated measures factor (time task was done before during after coffee)
# subject param identifies the data for grouping each individual together
  # in total we have 45 individuals (3 groups of 15)

# the table should show that there are low p-values (p-unc) for the Timepoint and Interaction rows meaning there is signficance for those measures
# now we need to visualize the results to investigate further
# Out:
#         Source         SS  DF1  DF2         MS          F         p-unc  \
# 0        Group  40.311111    2   42  20.155556   2.446942  9.880857e-02
# 1    TimePoint  69.644444    2   84  34.822222  31.147184  7.588754e-11
# 2  Interaction  57.777778    4   84  14.444444  12.920019  3.051011e-08
#
#         np2       eps
# 0  0.104361       NaN
# 1  0.425815  0.901879
# 2  0.380897       NaN

# %%
# using seaborn to make a nice barplot
sns.boxplot(data=df,hue="Group",y="TheData",x='TimePoint')

# this should show that pre-drinking coffee (timepoint 1) everyone performs the task equally well
# There are more differences in performance during and after drinking coffee (the heavy coffee drinkers do the worst)
# Out:
# <Axes: xlabel='TimePoint', ylabel='TheData'>
